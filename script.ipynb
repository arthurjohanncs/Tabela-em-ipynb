# %%
import pandas as pd

tabela = pd.read_csv("clientes_banco.csv")
display(tabela)

#para remober as linhas com valores nulos, podemos usar o método .dropna() do pandas.
tabela.dropna()
# Out:
#    ID_CLIENTE             NOME  IDADE          CIDADE      SALDO CATEGORIA  \
# 0         101        Ana Silva     28       São Paulo   14500.50    Bronze
# 1         102  Carlos Oliveira     45  Rio de Janeiro   89000.00      Gold
# 2         103    Mariana Costa     34  Belo Horizonte    2300.00    Bronze
# 3         104   Fernando Souza     52        Curitiba  150000.75  Platinum
# 4         105     Juliana Lima     29       São Paulo        NaN    Bronze
# 5         106    Lucas Pereira     61    Porto Alegre   42000.00    Silver
# 6         107    Beatriz Rocha     22  Rio de Janeiro     850.20    Bronze
# 7         108    Roberto Alves     39       São Paulo   95000.00      Gold
# 8         109   Camila Martins     31        Curitiba    3100.00    Bronze
# 9         110  Gustavo Ribeiro     48  Belo Horizonte  210000.00  Platinum
#
#     STATUS
# 0    Ativo
# 1    Ativo
# 2  Inativo
# 3    Ativo
# 4    Ativo
# 5    Ativo
# 6  Inativo
# 7    Ativo
# 8    Ativo
# 9    Ativo
# ...
